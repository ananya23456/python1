# %%
import pandas as pd
a = {'rollno':[1,2,3,4],'name':['anu','akhila','jennyfer','amalda']}
b = pd.DataFrame(a)
print (b)
# Out:
#    rollno      name
# 0       1       anu
# 1       2    akhila
# 2       3  jennyfer
# 3       4    amalda

# %%
a = [1,2,3,4]
b = pd.Series(a,index=["w","x","y","z"])
b = pd.DataFrame(a)
print(b.loc[0])
# Out:
# 0    1
# Name: 0, dtype: int64

# %%
import pandas as pd
a = {'rollno':[1,2,3,4],'name':['anu','akhila','jennyfer','amalda']}
b = pd.DataFrame(a)

print(b.loc[0])
# Out:
# rollno      1
# name      anu
# Name: 0, dtype: object

# %%
import pandas as pd 
a = pd.read_csv('day.csv')
# print(a.head(2))
print(a.tail())
# Out:
#     Numeric  Numeric-2 Numeric-Suffix
# 26       27         27           27th
# 27       28         28           28th
# 28       29         29           29th
# 29       30         30           30th
# 30       31         31           31st

# %%
import pandas as pd
list = [10,20,30,40]
s = pd.Series(list)
print("Series:")
print(s)
# Out:
# Series:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd 
dates = pd.date_range(start='20-11-2024',end='24-11-2024')
print("series of dates:")
print(dates)
# Out:
# series of dates:
# DatetimeIndex(['2024-11-20', '2024-11-21', '2024-11-22', '2024-11-23',
#                '2024-11-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
data = [[101,'Anu',85],[102,'Binu',90],[103,'Cathy',78]]
df = pd.DataFrame(data,columns=['rollno','name','mark'])
print("Data frame:")
print(df)
# Out:
# Data frame:
#    rollno   name  mark
# 0     101    Anu    85
# 1     102   Binu    90
# 2     103  Cathy    78

# %%
import pandas as pd
data ={
    'name':['Anu','Binu','Cathy'],
    'Age':[20,21,22],
    'mark':[85,90,78]
}
df=pd.DataFrame(data)
print("dataframe")
print(df)
# Out:
# dataframe
#     name  Age  mark
# 0    Anu   20    85
# 1   Binu   21    90
# 2  Cathy   22    78

# %%
import pandas as pd 
data ={
    'name':['Anu','Binu','Cathy','David','Eva','amal'],
    'mark':[85,90,78,88,95,89]
}
df =pd.DataFrame(data)
print("Head:")
print(df.head())
print("\ntail:")
print(df.tail())
# Out:
# Head:
#     name  mark
# 0    Anu    85
# 1   Binu    90
# 2  Cathy    78
# 3  David    88
# 4    Eva    95
#
# tail:
#     name  mark
# 1   Binu    90
# 2  Cathy    78
# 3  David    88
# 4    Eva    95
# 5   amal    89
